# %% [markdown]
# # 04 - Data Visualizations
#
# This notebook creates visualizations for campaign performance data.
#
# ## Objectives:
# - Create CTR over time charts
# - Visualize ROI comparisons
# - Create distribution plots
# - Build comprehensive dashboards
# - Save visualizations for reports

# %%
# Import libraries
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import sys
import os

sys.path.append('../src')
from data_processing import load_data
from visualizations import (plot_ctr_over_time, plot_roi_comparison, 
                           plot_metric_distribution, plot_campaign_overview, plot_top_performers)

# Create output directory for figures
os.makedirs('../outputs/figures', exist_ok=True)

# %%
# Load cleaned data
data_path = '../data/processed/cleaned_campaign_data.csv'
df = load_data(data_path, file_type='csv')

print(f"Data shape: {df.shape}")
